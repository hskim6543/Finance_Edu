# %% [markdown]
# # Python Installation

# %% [markdown]
# - [Anaconda Distribution](https://www.anaconda.com/download/#windows)

# %%
from IPython.display import Image 
Image("c:/python/images/PythonDownLoad.PNG", width=900, height=320)

# %% [markdown]
# - **[Pre-Installed](https://docs.anaconda.com/anaconda/packages/py3.6_win-64.html)   Packages when installing Anacond first time**

# %% [markdown]
# # Add not-yet installed packages

# %% [markdown]
# -  **If import not installed module then use package manager [pip](https://pypi.org/project/pip/) or [conda](https://conda.io/docs/index.html)** <br>
#       >conda install $PACKAGE_NAME <br>
#             >>`conda install pip3`  <br>
#             >>`pip install pip3`  <br>
#
#       >conda update $PACKAGE_NAME
#
#       > conda install -y ipython matplotlib pandas pytables scipy seaborn
#
#       > conda remove pytables
#
#       >conda list

# %% [markdown]
# # Virtual Environment

# %% [markdown]
# **- Sometimes we need virtual environment**
# - required python 2.xx
# - required python 3.5xx (currently 3.6xx)  <br>
# - required 32bit
#
# >set CONDA_FORCE_32BIT=1  __<font color=blue>[only for 32bit required]</font>__<br>
# >conda create --name py32_35 python=3.5
#
# > activate py32_35 or using mouse with window command
# > deactivate py32_35

# %%
from IPython.display import Image 
Image("c:/python/images/env2.7.PNG", width=300, height=160)

# %% [markdown]
# # Clouding Instances

# %% [markdown]
# - Jupyter Notebook:
#   - popular interactive development environment
#   - used for Python, R and Julia
# - terminal:
#   - allows for all typical system administration tasks
#   - allows to use helpful tools like Vim or gite

# %% [markdown]
# # More issues

# %% [markdown]
# - Jupyter notebook server related [here](http://jupyter-notebook.readthedocs.io/en/latest/index.html)
# - Jupyter notebook nbextension [For me](https://github.com/ipython-contrib/jupyter_contrib_nbextensions)
# - [Github](github.com)
