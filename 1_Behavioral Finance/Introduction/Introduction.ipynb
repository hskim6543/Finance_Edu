# %% [markdown]
# ## Orientation

# %% [markdown]
# 1. Why do we need critical thinking on traditional finance theory and methodology?
#   -  What is analytical thinking?
# 2. What is EMH (efficient market hypothesis)?
#   -Traditional asset pricing models and implications
# 3. Non-Traditional asset pricing models
#   - noise trading models
# 4. Psychological aspects of BF (behavioral finance)
# 5. Risk premium and prospect theory
# 6. BF variables and their implication on ML

# %% [markdown]
# ##   New Perspective Needed after the 2007 US financial crisis

# %% [markdown]
# -  2007년 금융위기 이후 경제학과 재무경제의 위기감 증대. Why?
#     -  학교: 전통적인 자산가격 결정론
#
#     -  주요경제서적: 비판적 측면 및 특이성(심리, 비합리성)을 강조
#
#     - 사회: 전통적인 방법론을 기초로 통계적인 방법 선호
#
# - New trend in finance and economics
#   - AI, active portfolio management, Blockchain
#
#   -  Economist, Analyst, Fund Manager의 역할이 애매
#     -  Robot advisor 시대의 도래와 새로운 역할
#     -  IT & Value-added Data generator or analyst

# %% [markdown]
# ## Most prone to Automation
# - Carl Benedikt Frey and Michael Osborne, Univ. Of Oxford, 2013.

# %% [markdown]
# - Telemakers (0.99)
# -Tax preparers (0.99)
# - Insurance Appraisers (0.98)
# - Umpires, referees, and Other sport officials (0.98)
# -  Legal Secretaries (0.98)
# -  Hosts and hostesses, restaurant, lounge, and coffee shop (0.97)
# -  Real estate brokers (0.97)
# -  Farm labor contractors (0.97)
# -  Secretaries and Administrative Assistants (0.96)
# -  Couriers and messengers (0.94)

# %% [markdown]
# ## Least prone to Automation

# %% [markdown]
# - Mental health and substitute abuse social workers (0.0031)
# - Choreographers (0.0040)
# - Physicians and surgeons (0.0042)
# -  Psychologists (0.0043)
# -  Human resource managers (0.0055)
# -  Computer systems analysts (0.0065)
# -  Anthropologists and Archaeologists (0.0077)
# -  Marine Engineers and naval architects (0.001)
# -  Sales managers (0.0013)
# -  Chief executives (0.0015)

# %% [markdown]
# ## World Economic Environment

# %% [markdown]
# - US Interest rate hikes and EM's crisis story
#   - Turkey, Venezuela
# - Trump’s unconventional trade sanction
# - Chinese excessive credit to non-financial firms, such as, state owned firms
# -  European’s extreme rightwing movement
# -  Brexit or pseudo-exit

# %% [markdown]
# ## Hart to explain US economy
#
# $\pi_t = \theta_t (u_t - u_t^*) + \lambda_t \pi_t^e + (1-\lambda_t ) \pi_{t-1}^* + \mu_t \pi_{imt} + \epsilon_t$
#
# - **Fact:** $\lambda_t \approx 1, \theta_t$ decrease

# %%
from IPython.display import Image
Image("c:/python/images/PhillipsCurve.jpg")

# %% [markdown]
# ### Questions

# %% [markdown]
# - Does US interest policy affect on the US economy?
# - Does it affect on the World economy?
# -  How does it do on YEN/USD?
# - How does it do on S&P500?
# - How does it do on Oil Price?

# %%
from IPython.display import Image
Image("c:/python/images/HedgeFundStrategy.png")

# %% [markdown]
# [IMF Datamapper](http://www.imf.org/external/datamapper/NGDP_RPCH@WEO/OEMDC/ADVEC/WEOWORLD)

# %% [markdown]
# ## Financial Analytics
#
# -  “The term used for describing the iterative process of proposing models and finding how well the data fit the models, and how to predict future outcomes from the models”
#
# - Financial Ana. Involves applying classical statistical       models and computerized algorithms to the financial market data and investment portfolios
#
# _Human is facing in a deluge of data. “Humans are not  very good at comprehending large set of data. One way out be visualization_
